# %%
43+60+16+41
# Out:
# 160

# %%
50-60
# Out:
# -10

# %%
5*5
# Out:
# 25

# %%
25/5
# Out:
# 5.0

# %%
25/6
# Out:
# 4.166666666666667

# %%
25//6
# Out:
# 4

# %%
2*60+30
# Out:
# 150

# %%
30+2*60
# Out:
# 150

# %%
(30+2)*60
# Out:
# 1920

# %%
my_variable=1

my_variable
# Out:
# 1

# %%
x=160
y=x/60
y
# Out:
# 2.6666666666666665

# %%
x=160
y=x/60
type(y)
# Out:
# float

# %%
total_min = 43+42+5
total_hr=total_min/60
total_hr
# Out:
# 1.5
