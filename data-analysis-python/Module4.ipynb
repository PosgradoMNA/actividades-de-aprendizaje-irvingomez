# %% [markdown]
# # Ciencia y Analítica de Datos
# ## Curso IBM - Data Analysis with Python
# ### Module 4 - Model Development
# ### Irvin Gomez Esquivel - A00361034

# %% [markdown]
# ### Model Development
# Un modelo se puede ver como una ecuación matemática para predecir un valor dado dado uno o más valores
# Relaciona una o más variables independientes a variables dependientes
#
# Usualmente mientras más datos relevantes tenemos, más acertado será el modelo.

# %% [markdown]
# ### Regresión Lineal y Regresión Lineal Múltiple
#
# Regresión lienal se refiere a una variable independiente para hacer una predicción
#
# Regresión lineal múltiple se refiere a múltiples variables para hacer la predicción.

# %% [markdown]
# ### Regresión Lineal Simple
# 1. El predictor (independiente) variable - x
# 2. El objetivo (dependiente) variable - y
#
# Guardamos los valores en 2 dataframes
#
# Usamos las variables para hecer Fit
# Con los valores obtenidos podemos predecir.

# %%
from sklearn.linear_model import LinearRegression
lm=LinearRegression()

#definimos el predictor y la variable objetivo
X = df[["highway-mpg"]]
Y = df["price"]

#luego usamos fit para el modelo
lm.fit(X, Y)

Yhat=lm.predict(X)

# %% [markdown]
# ### Regresion Lineal Múltiple
# Se usa cuando se tiene una variable objetivo (Y)
# y se tienen mñas de 2 variables predictor

# %%
Z = df[["horsepower", "curb-weight", "engine-size", "highway-mpg"]]

lm.fit (Z, df["price"])

Yhat = lm.predict(X)

# %% [markdown]
# ### Model Evaluation Using Visualization
#
# #### Regresion Plot
# Muestra una combinación de scatterploy y la regresión lieneal entrenada.

# %%
import seaborn as sns

sns.regplot(x="highway-mpg", y="price", data=df)
plt.ylim(0,)

# %% [markdown]
# Podemos usar seaborn para dibujar el valor residual

# %%
import seaborn as sns
sns.residplot(df["highway-mpg"], df["price"])

# %% [markdown]
# También podemos usar Distribution Plots

# %%
import seaborn as sns

axl = sns.distplot(dt["price"], hist=False, color="r", label="Actial Value")
sns.displot(Yhat, hist=False, color="b", label="Fitted Values", ax=axl)

# %% [markdown]
# ### Polinomial Regression and Pipelines
# Las regresiones polinomiales son un caso especial del modelo de regresion lineal general.
# Util para describir relaciones curvilíneas
#
# Quadratica - segundo order
# Cúbica - tercer grado
# Higher Order

# %%
f=np.polyfit(x,y,3)
p=np.polyld(f)
print(p)

# %% [markdown]
# Pre-processing

# %%
from sklearn.preprocessing import StandardScaler
SCALE=StandardScaler()
SCALE.fit(x_data[["horsepower", "highway-mpg"]])
x_scale=SCALE.transform(x_data[["horsepower", "highway-mpg"]])

# %% [markdown]
# ### Pipelines
# Hay muchos pasos para llegar a una predicción
# Normalización
# Transformación
# Regresión Lineal

# %% [markdown]
# ### Medidas para evaluación In-Sample
# Mean Squared Error (MSE)

# %%
from sklearn.metrics import mean_squared_errror
mean_squared_error(dr["price"], Y_predict_simplefit)

# %% [markdown]
# ### R-squared
# Es una medida para determinar que tan cercano es el modelo.
#
# Si R-squared es negativo pudiera ser porque el modelo está sobreentrenado

# %% [markdown]
# ### Predicción y toma de decisiones
# Para determinar el mejor fit final, buscamos una combinación de
# * Los valores predecidos hacen sentido
# * Visualiazción
# * Medidas numéricas de evalauaicón
# * Comparación de Modelos

# %%
# primero entrenamos el modelo
lm.fit(df["highway-mpg", dr["prices"]])

#ahora vamos a predecir el precio de un auto de 30 millas por galón en carretera
lm.predict(30)

# %% [markdown]
# Para predecir números en un rango

# %%
import numpy as np
new_input=np.arrange[1,101,1].reshape(-1,1)

# %% [markdown]
# # Lab for Module 4

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv'

# %%
df = pd.read_csv(path)
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()
lm
# Out:
# LinearRegression()

# %%
X = df[['highway-mpg']]
Y = df['price']

# %%
lm.fit(X,Y)
# Out:
# LinearRegression()

# %%
Yhat=lm.predict(X)
Yhat[0:5]
# Out:
# array([16236.50464347, 16236.50464347, 17058.23802179, 13771.3045085 ,
#        20345.17153508])

# %%
lm.intercept_
# Out:
# 38423.3058581574

# %%
lm.coef_
# Out:
# array([-821.73337832])

# %% [markdown]
# ## Question #1 a):
#
# Create a linear regression object called "lm1".

# %%
lm1 = LinearRegression()
lm1
# Out:
# LinearRegression()

# %% [markdown]
# ## Question #1 b): ¶
#
# Train the model using "engine-size" as the independent variable and "price" as the dependent variable?

# %%
lm1.fit(df[['engine-size']], df[['price']])
lm1
# Out:
# LinearRegression()

# %% [markdown]
# ## Question #1 c):
#
# Find the slope and intercept of the model.

# %%
lm1.coef_
# Out:
# array([[166.86001569]])

# %%
lm1.intercept_
# Out:
# array([-7963.33890628])

# %% [markdown]
# ## Question #1 d): ¶
#
# What is the equation of the predicted line? You can use x and yhat or "engine-size" or "price".

# %%
# using X and Y  
Yhat=-7963.34 + 166.86*X

Price=-7963.34 + 166.86*df['engine-size']

# %% [markdown]
# ## Multiple linear regression

# %%
Z = df[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]

# %%
lm.fit(Z, df['price'])
# Out:
# LinearRegression()

# %%
lm.intercept_
# Out:
# -15806.624626329227

# %%
lm.coef_
# Out:
# array([53.49574423,  4.70770099, 81.53026382, 36.05748882])

# %% [markdown]
# ##  Question #2 a): ¶
# Create and train a Multiple Linear Regression model "lm2" where the response variable is "price", and the predictor variable is "normalized-losses" and "highway-mpg".

# %%
lm2 = LinearRegression()
lm2.fit(df[['normalized-losses' , 'highway-mpg']],df['price'])
# Out:
# LinearRegression()

# %% [markdown]
# ## Question #2 b): ¶
# Find the coefficient of the model.

# %%
lm2.coef_
# Out:
# array([   1.49789586, -820.45434016])

# %% [markdown]
# ## Model Evaluation Using Visualization

# %%
# import the visualization package: seaborn
import seaborn as sns
# %matplotlib inline

# %%
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.regplot(x="highway-mpg", y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 48164.712729686646)

# %%
plt.figure(figsize=(width, height))
sns.regplot(x="peak-rpm", y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 47414.1)

# %% [markdown]
# ## Question #3:
# Given the regression plots above, is "peak-rpm" or "highway-mpg" more strongly correlated with "price"? Use the method ".corr()" to verify your answer.

# %%
df[["peak-rpm","highway-mpg","price"]].corr()
# Out:
#              peak-rpm  highway-mpg     price
# peak-rpm     1.000000    -0.058598 -0.101616
# highway-mpg -0.058598     1.000000 -0.704692
# price       -0.101616    -0.704692  1.000000

# %% [markdown]
# ## Residual plot

# %%
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.residplot(x=df['highway-mpg'],y=df['price'])
plt.show()

# %%
Y_hat = lm.predict(Z)

# %%
plt.figure(figsize=(width, height))


ax1 = sns.distplot(df['price'], hist=False, color="r", label="Actual Value")
sns.distplot(Y_hat, hist=False, color="b", label="Fitted Values" , ax=ax1)


plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Price (in dollars)')
plt.ylabel('Proportion of Cars')

plt.show()
plt.close()
# Out:
# C:\Users\irvin\AppData\Local\Temp\ipykernel_46660\4196657742.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1 = sns.distplot(df['price'], hist=False, color="r", label="Actual Value")
# C:\Users\irvin\AppData\Local\Temp\ipykernel_46660\4196657742.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# ## Polynomial Regression and Pipelines

# %%
def PlotPolly(model, independent_variable, dependent_variabble, Name):
    x_new = np.linspace(15, 55, 100)
    y_new = model(x_new)

    plt.plot(independent_variable, dependent_variabble, '.', x_new, y_new, '-')
    plt.title('Polynomial Fit with Matplotlib for Price ~ Length')
    ax = plt.gca()
    ax.set_facecolor((0.898, 0.898, 0.898))
    fig = plt.gcf()
    plt.xlabel(Name)
    plt.ylabel('Price of Cars')

    plt.show()
    plt.close()

# %%
x = df['highway-mpg']
y = df['price']

# %%
# Here we use a polynomial of the 3rd order (cubic) 
f = np.polyfit(x, y, 3)
p = np.poly1d(f)
print(p)
# Out:
#         3         2
# -1.557 x + 204.8 x - 8965 x + 1.379e+05

# %%
PlotPolly(p, x, y, 'highway-mpg')

# %%
np.polyfit(x, y, 3)
# Out:
# array([-1.55663829e+00,  2.04754306e+02, -8.96543312e+03,  1.37923594e+05])

# %% [markdown]
# ## Question #4:
# Create 11 order polynomial model with the variables x and y from above.

# %%
f1 = np.polyfit(x, y, 11)
p1 = np.poly1d(f1)
print(p1)
PlotPolly(p1,x,y, 'Highway MPG')
# Out:
#             11             10             9           8         7
# -1.243e-08 x  + 4.722e-06 x  - 0.0008028 x + 0.08056 x - 5.297 x
#           6        5             4             3             2
#  + 239.5 x - 7588 x + 1.684e+05 x - 2.565e+06 x + 2.551e+07 x - 1.491e+08 x + 3.879e+08

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pr=PolynomialFeatures(degree=2)
pr
# Out:
# PolynomialFeatures()

# %%
Z_pr=pr.fit_transform(Z)

# %%
Z.shape
# Out:
# (201, 4)

# %%
Z_pr.shape
# Out:
# (201, 15)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
Input=[('scale',StandardScaler()), ('polynomial', PolynomialFeatures(include_bias=False)), ('model',LinearRegression())]

# %%
pipe=Pipeline(Input)
pipe
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('polynomial', PolynomialFeatures(include_bias=False)),
#                 ('model', LinearRegression())])

# %%
Z = Z.astype(float)
pipe.fit(Z,y)
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('polynomial', PolynomialFeatures(include_bias=False)),
#                 ('model', LinearRegression())])

# %%
ypipe=pipe.predict(Z)
ypipe[0:4]
# Out:
# array([13102.74784201, 13102.74784201, 18225.54572197, 10390.29636555])

# %% [markdown]
# ## Question #5:
# Create a pipeline that standardizes the data, then produce a prediction using a linear regression model using the features Z and target y.

# %%
Input=[('scale',StandardScaler()),('model',LinearRegression())]

pipe=Pipeline(Input)

pipe.fit(Z,y)

ypipe=pipe.predict(Z)
ypipe[0:10]
# Out:
# array([13699.11161184, 13699.11161184, 19051.65470233, 10620.36193015,
#        15521.31420211, 13869.66673213, 15456.16196732, 15974.00907672,
#        17612.35917161, 10722.32509097])

# %% [markdown]
# ## Measures for In-Sample Evaluation

# %%
#highway_mpg_fit
lm.fit(X, Y)
# Find the R^2
print('The R-square is: ', lm.score(X, Y))
# Out:
# The R-square is:  0.4965911884339176

# %%
Yhat=lm.predict(X)
print('The output of the first four predicted value is: ', Yhat[0:4])
# Out:
# The output of the first four predicted value is:  [16236.50464347 16236.50464347 17058.23802179 13771.3045085 ]

# %%
from sklearn.metrics import mean_squared_error

# %%
mse = mean_squared_error(df['price'], Yhat)
print('The mean square error of price and predicted value is: ', mse)
# Out:
# The mean square error of price and predicted value is:  31635042.944639888

# %% [markdown]
# ## Model 2: Multiple Linear Regression

# %%
# fit the model 
lm.fit(Z, df['price'])
# Find the R^2
print('The R-square is: ', lm.score(Z, df['price']))
# Out:
# The R-square is:  0.8093562806577457

# %%
Y_predict_multifit = lm.predict(Z)

# %%
print('The mean square error of price and predicted value using multifit is: ', \
      mean_squared_error(df['price'], Y_predict_multifit))
# Out:
# The mean square error of price and predicted value using multifit is:  11980366.87072649

# %% [markdown]
# ## Model 3: Polynomial Fit

# %%
from sklearn.metrics import r2_score

# %%
r_squared = r2_score(y, p(x))
print('The R-square value is: ', r_squared)
# Out:
# The R-square value is:  0.674194666390652

# %%
mean_squared_error(df['price'], p(x))
# Out:
# 20474146.426361207

# %% [markdown]
# ## Prediction and Decision Making

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
new_input=np.arange(1, 100, 1).reshape(-1, 1)

# %%
lm.fit(X, Y)
lm
# Out:
# LinearRegression()

# %%
yhat=lm.predict(new_input)
yhat[0:5]
# Out:
# C:\Users\irvin\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([37601.57247984, 36779.83910151, 35958.10572319, 35136.37234487,
#        34314.63896655])

# %%
plt.plot(new_input, yhat)
plt.show()

# %% [markdown]
# # Graded Review Questions

# %% [markdown]
# ![Modulo 4 - Pregunta 1.png](data:image/png;base64,...)

# %% [markdown]
# ![Modulo 4 - Pregunta 2.png](data:image/png;base64,...)

# %% [markdown]
# ![Modulo 4 - Pregunta 3 y 4.png](data:image/png;base64,...)

# %% [markdown]
# ![Modulo 4 - Pregunta 5.png](data:image/png;base64,...)
